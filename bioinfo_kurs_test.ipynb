# %% [markdown]
# <a href="https://colab.research.google.com/github/rodirk/spezielle_bioinfo_2_22/blob/main/bioinfo_kurs_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ipympl

# %%
import skimage
import numpy as np
import skimage.io
import skimage.viewer
import matplotlib.pyplot as plt
import ipympl
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: Viewer requires Qt
#   after removing the cwd from sys.path.

# %%
# %matplotlib widget

# %%
# read the image
image = skimage.io.imread("/content/drive/MyDrive/data/chair.jpg")

#display the image

fig,ax= plt.subplots()
plt.imshow(image)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
from google.colab import output
output.disable_custom_widget_manager()

# %% [markdown]
# ### Pixel manipulatuion

# %%
#read image
image2 = skimage.io.imread("/content/drive/MyDrive/data/maize-root-cluster.jpg")

#display the image

fig,ax= plt.subplots()
plt.imshow(image2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#keep only high intensity pixels

image2[image2 < 128] =0

#display mod image2
fig,ax= plt.subplots()
plt.imshow(image2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Color conversion to grayscale
